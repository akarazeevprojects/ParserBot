# %%
# %load_ext autoreload
# %autoreload 2

from telegram.ext import Updater, CommandHandler, MessageHandler, Filters
import numpy as np
import threading
import argparse
import telegram
import sys
import os
import pickle
import utils
import json
import time
from emoji import emojize

sys.argv = ['--proxy 1']
parser = argparse.ArgumentParser(description="Bot to parse news from FPMI's site")
parser.add_argument('--proxy', dest='proxy', type=int,
                    default=1, help='use proxy or not')

bot = None
info_text = 'NOT IMPLEMENTED'
fpmi_url = 'https://mipt.ru/education/departments/fpmi/'
channel_id = -1001180214136  # FPMI_announcements.
pause = 1.0


if os.path.exists(utils.PKL) is False:
    data = list()
    with open(utils.PKL, 'wb') as f:
        pickle.dump(data, f)


def announce():
    # Get all news from site.
    fresh_news = utils.get_info(fpmi_url)
    # Load dumped news from .pkl file.
    loaded_news = utils.load_news()
    # Find difference between fresh and dumped news.
    news_list = utils.diff_news(fresh_news, loaded_news)
    
#     fresh_titles = utils.get_titles(utils.get_sorted(fresh_news))
#     loaded_titles = utils.get_titles(utils.get_sorted(loaded_news))
#     print(fresh_titles)
#     print(loaded_titles)
    
    news_list = utils.get_sorted(news_list)
    print(utils.get_titles(news_list))

    # If there is at least one fresh announcement -- post it.
    if len(news_list) == 0:
        print('-> nothing new :(')
    else:
        print('-> announce')
        to_announce = news_list[0]
        try:
            if to_announce not in loaded_news:
                text = utils.compose_announcement(to_announce)
                # Make announcement.
    #             bot.send_message(chat_id=channel_id, text=text, parse_mode=telegram.ParseMode.MARKDOWN, timeout=9999)
                # Save updated news.

                if 'ФПМИ продолжает поддерживать важные образовательные проекты для школьников' not in to_announce['title']:
                    loaded_news.append(to_announce)
                    print('appended')
                    utils.save_news(loaded_news)
                    print('-> done')
                else:
                    print('-> missed')
            else:
                print('-> duplicate :(')
        except telegram.error.TimedOut as e:
            print('-> skipping this event due to Timed Out')
            print(e)

        
announcer = utils.Looper(announce, pause=pause)  # `pause` == seconds.
        

def help(bot, update):
    update.message.reply_text(info_text)
    return


def main():
#     global bot
#     token = utils.get_token('res/token.json')

#     args = parser.parse_args()
#     if args.proxy == 1:
#         print('-> USE PROXY')
#         req = telegram.utils.request.Request(proxy_url='socks5h://127.0.0.1:9050',
#                                              read_timeout=30, connect_timeout=20,
#                                              con_pool_size=10)
#         bot = telegram.Bot(token=token, request=req)
#     elif args.proxy == 0:
#         print('-> NO PROXY')
#         bot = telegram.Bot(token=token)
#     else:
#         raise ValueError('Wrong proxy.')

    announcer.start()
    
#     updater = Updater(bot=bot)
#     dp = updater.dispatcher

#     dp.add_handler(CommandHandler('help', help))
#     dp.add_handler(CommandHandler('start', help))
#     dp.add_handler(MessageHandler(Filters.text, help))

#     updater.start_polling()
#     updater.idle()


if __name__ == '__main__':
    main()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ['Новый набор в кружки по искусственному интеллекту', 'Optimization at work', 'Семинар AI@MIPT', 'Аветисян А.И. "Современные проблемы системного программирования"', 'Workshop on graphs, networks, and their applications', '15th Workshop on Algorithms and Models for the Web Graph', 'The 8th International Conference on Network Analysis', 'О школе', 'Geometry, Dynamics, Integrable Systems – GDIS 2018', 'Эрик Госье "Семантическое аннотирование и вопросно-ответные системы BioASQ"', 'Лаборатория гибридных интеллектуальных систем ФПМИ приглашает студентов и выпускников на работу', 'ФПМИ продолжает поддерживать важные образовательные проекты для школьников', "В Канаде при поддержке ФПМИ состоится конференция по блокчейну BTS '18", 'МФТИ и Тинькофф Банк запускают бесплатные курсы для школьников', 'ФПМИ запускает курсы по нейронным сетям для старшеклассников', '5 сентября - старт межкафедрального семинара по дискретной математике', 'Big Data Conference 2018', 'Хакатон «Mix Hack»']
# -> announce
# appended
# -> done
# ['Optimization at work', 'Семинар AI@MIPT', 'Аветисян А.И. "Современные проблемы системного программирования"', 'Workshop on graphs, networks, and their applications', '15th Workshop on Algorithms and Models for the Web Graph', 'The 8th International Conference on Network Analysis', 'О школе', 'Geometry, Dynamics, Integrable Systems – GDIS 2018', 'Эрик Госье "Семантическое аннотирование и вопросно-ответные системы BioASQ"', 'Лаборатория гибридных интеллектуальных систем ФПМИ приглашает студентов и выпускников на работу', 'ФПМИ продолжает поддерживать важные образовательные проекты для школьников', "В Канаде при поддержке ФПМИ состоится конференция по блокчейну BTS '18", 'МФТИ и Тинькофф Банк запускают бесплатные курсы для школьников', 'ФПМИ запускает курсы по нейронным сетям для старшеклассников', '5 сентября - старт межкафедрального семинара по дискретной математике', 'Big Data Conference 2018', 'Хакатон «Mix Hack»']
# -> announce
# appended
# -> done
# ['Семинар AI@MIPT', 'Аветисян А.И. "Современные проблемы системного программирования"', 'Workshop on graphs, networks, and their applications', '15th Workshop on Algorithms and Models for the Web Graph', 'The 8th International Conference on Network Analysis', 'О школе', 'Geometry, Dynamics, Integrable Systems – GDIS 2018', 'Эрик Госье "Семантическое аннотирование и вопросно-ответные системы BioASQ"', 'Лаборатория гибридных интеллектуальных систем ФПМИ приглашает студентов и выпускников на работу', 'ФПМИ продолжает поддерживать важные образовательные проекты для школьников', "В Канаде при поддержке ФПМИ состоится конференция по блокчейну BTS '18", 'МФТИ и Тинькофф Банк запускают бесплатные курсы для школьников', 'ФПМИ запускает курсы по нейронным сетям для старшеклассников', '5 сентября - старт межкафедрального семинара по дискретной математике', 'Big Data Conference 2018', 'Хакатон «Mix Hack»']
# -> announce
# appended
# -> done
# ['Аветисян А.И. "Современные проблемы системного программирования"', 'Workshop on graphs, networks, and their applications', '15th Workshop on Algorithms and Models for the Web Graph', 'The 8th International Conference on Network Analysis', 'О школе', 'Geometry, Dynamics, Integrable Systems – GDIS 2018', 'Эрик Госье "Семантическое аннотирование и вопросно-ответные системы BioASQ"', 'Лаборатория гибридных интеллектуальных систем ФПМИ приглашает студентов и выпускников на работу', 'ФПМИ продолжает поддерживать важные образовательные проекты для школьников', "В Канаде при поддержке ФПМИ состоится конференция по блокчейну BTS '18", 'МФТИ и Тинькофф Банк запускают бесплатные курсы для школьников', 'ФПМИ запускает курсы по нейронным сетям для старшеклассников', '5 сентября - старт межкафедрального семинара по дискретной математике', 'Big Data Conference 2018', 'Хакатон «Mix Hack»']
# -> announce
# appended
# -> done
# ['Workshop on graphs, networks, and their applications', '15th Workshop on Algorithms and Models for the Web Graph', 'The 8th International Conference on Network Analysis', 'О школе', 'Geometry, Dynamics, Integrable Systems – GDIS 2018', 'Эрик Госье "Семантическое аннотирование и вопросно-ответные системы BioASQ"', 'Лаборатория гибридных интеллектуальных систем ФПМИ приглашает студентов и выпускников на работу', 'ФПМИ продолжает поддерживать важные образовательные проекты для школьников', "В Канаде при поддержке ФПМИ состоится конференция по блокчейну BTS '18", 'МФТИ и Тинькофф Банк запускают бесплатные курсы для школьников', 'ФПМИ запускает курсы по нейронным сетям для старшеклассников', '5 сентября - старт межкафедрального семинара по дискретной математике', 'Big Data Conference 2018', 'Хакатон «Mix Hack»']
# -> announce
# appended
# -> done
# ['15th Workshop on Algorithms and Models for the Web Graph', 'The 8th International Conference on Network Analysis', 'О школе', 'Geometry, Dynamics, Integrable Systems – GDIS 2018', 'Эрик Госье "Семантическое аннотирование и вопросно-ответные системы BioASQ"', 'Лаборатория гибридных интеллектуальных систем ФПМИ приглашает студентов и выпускников на работу', 'ФПМИ продолжает поддерживать важные образовательные проекты для школьников', "В Канаде при поддержке ФПМИ состоится конференция по блокчейну BTS '18", 'МФТИ и Тинькофф Банк запускают бесплатные курсы для школьников', 'ФПМИ запускает курсы по нейронным сетям для старшеклассников', '5 сентября - старт межкафедрального семинара по дискретной математике', 'Big Data Conference 2018', 'Хакатон «Mix Hack»']
# -> announce
# appended
# -> done
# ['The 8th International Conference on Network Analysis', 'О школе', 'Geometry, Dynamics, Integrable Systems – GDIS 2018', 'Эрик Госье "Семантическое аннотирование и вопросно-ответные системы BioASQ"', 'Лаборатория гибридных интеллектуальных систем ФПМИ приглашает студентов и выпускников на работу', 'ФПМИ продолжает поддерживать важные образовательные проекты для школьников', "В Канаде при поддержке ФПМИ состоится конференция по блокчейну BTS '18", 'МФТИ и Тинькофф Банк запускают бесплатные курсы для школьников', 'ФПМИ запускает курсы по нейронным сетям для старшеклассников', '5 сентября - старт межкафедрального семинара по дискретной математике', 'Big Data Conference 2018', 'Хакатон «Mix Hack»']
# -> announce
# appended
# -> done
# ['О школе', 'Geometry, Dynamics, Integrable Systems – GDIS 2018', 'Эрик Госье "Семантическое аннотирование и вопросно-ответные системы BioASQ"', 'Лаборатория гибридных интеллектуальных систем ФПМИ приглашает студентов и выпускников на работу', 'ФПМИ продолжает поддерживать важные образовательные проекты для школьников', "В Канаде при поддержке ФПМИ состоится конференция по блокчейну BTS '18", 'МФТИ и Тинькофф Банк запускают бесплатные курсы для школьников', 'ФПМИ запускает курсы по нейронным сетям для старшеклассников', '5 сентября - старт межкафедрального семинара по дискретной математике', 'Big Data Conference 2018', 'Хакатон «Mix Hack»']
# -> announce
# appended
# -> done
# ['Geometry, Dynamics, Integrable Systems – GDIS 2018', 'Эрик Госье "Семантическое аннотирование и вопросно-ответные системы BioASQ"', 'Лаборатория гибридных интеллектуальных систем ФПМИ приглашает студентов и выпускников на работу', 'ФПМИ продолжает поддерживать важные образовательные проекты для школьников', "В Канаде при поддержке ФПМИ состоится конференция по блокчейну BTS '18", 'МФТИ и Тинькофф Банк запускают бесплатные курсы для школьников', 'ФПМИ запускает курсы по нейронным сетям для старшеклассников', '5 сентября - старт межкафедрального семинара по дискретной математике', 'Big Data Conference 2018', 'Хакатон «Mix Hack»']
# -> announce
# appended
# -> done
# ['Эрик Госье "Семантическое аннотирование и вопросно-ответные системы BioASQ"', 'Лаборатория гибридных интеллектуальных систем ФПМИ приглашает студентов и выпускников на работу', 'ФПМИ продолжает поддерживать важные образовательные проекты для школьников', "В Канаде при поддержке ФПМИ состоится конференция по блокчейну BTS '18", 'МФТИ и Тинькофф Банк запускают бесплатные курсы для школьников', 'ФПМИ запускает курсы по нейронным сетям для старшеклассников', '5 сентября - старт межкафедрального семинара по дискретной математике', 'Big Data Conference 2018', 'Хакатон «Mix Hack»']
# -> announce
# appended
# -> done
# ['Лаборатория гибридных интеллектуальных систем ФПМИ приглашает студентов и выпускников на работу', 'ФПМИ продолжает поддерживать важные образовательные проекты для школьников', "В Канаде при поддержке ФПМИ состоится конференция по блокчейну BTS '18", 'МФТИ и Тинькофф Банк запускают бесплатные курсы для школьников', 'ФПМИ запускает курсы по нейронным сетям для старшеклассников', '5 сентября - старт межкафедрального семинара по дискретной математике', 'Big Data Conference 2018', 'Хакатон «Mix Hack»']
# -> announce
# appended
# -> done
# ['ФПМИ продолжает поддерживать важные образовательные проекты для школьников', "В Канаде при поддержке ФПМИ состоится конференция по блокчейну BTS '18", 'МФТИ и Тинькофф Банк запускают бесплатные курсы для школьников', 'ФПМИ запускает курсы по нейронным сетям для старшеклассников', '5 сентября - старт межкафедрального семинара по дискретной математике', 'Big Data Conference 2018', 'Хакатон «Mix Hack»']
# -> announce
# -> missed
# ['ФПМИ продолжает поддерживать важные образовательные проекты для школьников', "В Канаде при поддержке ФПМИ состоится конференция по блокчейну BTS '18", 'МФТИ и Тинькофф Банк запускают бесплатные курсы для школьников', 'ФПМИ запускает курсы по нейронным сетям для старшеклассников', '5 сентября - старт межкафедрального семинара по дискретной математике', 'Big Data Conference 2018', 'Хакатон «Mix Hack»']
# -> announce
# -> missed
# ['ФПМИ продолжает поддерживать важные образовательные проекты для школьников', "В Канаде при поддержке ФПМИ состоится конференция по блокчейну BTS '18", 'МФТИ и Тинькофф Банк запускают бесплатные курсы для школьников', 'ФПМИ запускает курсы по нейронным сетям для старшеклассников', '5 сентября - старт межкафедрального семинара по дискретной математике', 'Big Data Conference 2018', 'Хакатон «Mix Hack»']
# -> announce
# -> missed

# %%
# %load_ext autoreload
# %autoreload 2

from telegram.ext import Updater, CommandHandler, MessageHandler, Filters
import numpy as np
import threading
import argparse
import telegram
import sys
import os
import pickle
import utils
import json
import time
from emoji import emojize

sys.argv = ['--proxy 1']
parser = argparse.ArgumentParser(description="Bot to parse news from FPMI's site")
parser.add_argument('--proxy', dest='proxy', type=int,
                    default=1, help='use proxy or not')

bot = None
info_text = 'NOT IMPLEMENTED'
fpmi_url = 'https://mipt.ru/education/departments/fpmi/'
channel_id = -1001180214136  # FPMI_announcements.
pause = 20.0


if os.path.exists(utils.PKL) is False:
    data = list()
    with open(utils.PKL, 'wb') as f:
        pickle.dump(data, f)


def announce():
    # Get all news from site.
    fresh_news = utils.get_info(fpmi_url)
    # Load dumped news from .pkl file.
    loaded_news = utils.load_news()
    # Find difference between fresh and dumped news.
    news_list = utils.diff_news(fresh_news, loaded_news)
    
    news_list = utils.get_sorted(news_list)

    # If there is at least one fresh announcement -- post it.
    if len(news_list) == 0:
        print('-> nothing new :(')
    else:
        print('-> announce')
        to_announce = news_list[0]
        try:
            if to_announce not in loaded_news:
                text = utils.compose_announcement(to_announce)
                # Make announcement.
                bot.send_message(chat_id=channel_id, text=text, parse_mode=telegram.ParseMode.MARKDOWN, timeout=9999)
                # Save updated news.

                loaded_news.append(to_announce)
                print(to_announce)
                print('-> appended')
                utils.save_news(loaded_news)
                print('-> done')
            else:
                print('-> duplicate :(')
        except telegram.error.TimedOut as e:
            print('-> skipping this event due to Timed Out')
            print(e)

        
announcer = utils.Looper(announce, pause=pause)  # `pause` == seconds.
        

def help(bot, update):
    update.message.reply_text(info_text)
    return


def main():
    global bot
    token = utils.get_token('res/token.json')

    args = parser.parse_args()
    if args.proxy == 1:
        print('-> USE PROXY')
        req = telegram.utils.request.Request(proxy_url='socks5h://127.0.0.1:9050',
                                             read_timeout=30, connect_timeout=20,
                                             con_pool_size=10)
        bot = telegram.Bot(token=token, request=req)
    elif args.proxy == 0:
        print('-> NO PROXY')
        bot = telegram.Bot(token=token)
    else:
        raise ValueError('Wrong proxy.')

    announcer.start()
    
    updater = Updater(bot=bot)
    dp = updater.dispatcher

    dp.add_handler(CommandHandler('help', help))
    dp.add_handler(CommandHandler('start', help))
    dp.add_handler(MessageHandler(Filters.text, help))

    updater.start_polling()
    updater.idle()


if __name__ == '__main__':
    main()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# -> USE PROXY
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-7f8aca48c063> in <module>()
#     107
#     108 if __name__ == '__main__':
# --> 109     main()
#
# <ipython-input-3-7f8aca48c063> in main()
#      85         req = telegram.utils.request.Request(proxy_url='socks5h://127.0.0.1:9050',
#      86                                              read_timeout=30, connect_timeout=20,
# ---> 87                                              con_pool_size=10)
#      88         bot = telegram.Bot(token=token, request=req)
#      89     elif args.proxy == 0:
#
# /usr/local/lib/python3.6/site-packages/telegram/utils/request.py in __init__(self, con_pool_size, proxy_url, urllib3_proxy_kwargs, connect_timeout, read_timeout)
#     109                 except ImportError:
#     110                     raise RuntimeError('PySocks is missing')
# --> 111                 mgr = SOCKSProxyManager(proxy_url, **kwargs)
#     112             else:
#     113                 mgr = urllib3.proxy_from_url(proxy_url, **kwargs)
#
# /usr/local/lib/python3.6/site-packages/telegram/vendor/ptb_urllib3/urllib3/contrib/socks.py in __init__(self, proxy_url, username, password, num_pools, headers, **connection_pool_kw)
#     158         else:
#     159             raise ValueError(
# --> 160                 "Unable to determine SOCKS version from %s" % proxy_url
#     161             )
#     162
#
# ValueError: Unable to determine SOCKS version from socks5h://127.0.0.1:9050
